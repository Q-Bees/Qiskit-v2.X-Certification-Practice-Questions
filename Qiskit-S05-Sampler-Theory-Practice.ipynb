# %% [markdown]
# # Qiskit Certification – Section 5 Theory Practice
#
# Section 5: **Use the sampler primitive**
#
# Topics covered here:
# - Set sampler primitive options such as resilience levels
# - Bypass runtime error mitigations and implement your own
# - Understand the theoretical background behind the sampler primitive
#
# The quiz has 20 intermediate to advanced level multiple-choice questions with A, B, C and D options, to test conceptual understanding and code-related knowledge. It covers using the Sampler primitive, setting options like resilience levels, bypassing runtime error mitigations for custom implementations. It also, dives deeper into advanced usage, error mitigation via Pauli Twirling, and pulse level techniques in Dynamical Decoupling and the mathematical/theoretical foundations drawing from the Qiskit Runtime Primitives V2 video and Sampler options documentation.

# %% [markdown]
# **Q1** You need to estimate the probability distribution over measurement outcomes for a circuit executed on a real quantum device. Which IBM Runtime primitive should you choose?
#
# - A
# Session alone, without primitives
#
# - B
# Estimator
#
# - C
# Sampler
#
# - D
# Backend.run with no primitive
#
# **Answer**: C

# %% [markdown]
# **Q2** You want to write Qiskit code that runs a simple quantum circuit on real hardware using Sampler. Which combination is required to target IBM Quantum hardware via IBM Runtime?
#
# - A
# Use AerSimulator directly instead of IBM Runtime
#
# - B
# Use IBM Runtime Service with a hardware backend and pass it to Sampler
#
# - C
# Create a Sampler with no provider and rely on default local simulation
#
# - D
# Only use Estimator because Sampler is not supported on hardware
#
# **Answer**: B

# %% [markdown]
# **Q3** What is the primary purpose of the Sampler primitive in Qiskit Runtime?
#
# - A
# To simulate quantum noise models
#
# - B
# To generate quasi-probability distributions from quantum circuits
#
# - C
# To compile quantum circuits into gate sequences
#
# - D
# To measure expectation values of observables
#
#
# **Answer**: B

# %% [markdown]
# **Q4** How do you set options for the Sampler primitive in V2?
#
# - A
# By modifying the backend configuration file
#
# - B
# By using the set_parameters() method
#
# - C
# By creating an Options object and assigning it to sampler.options
#
# - D
# By passing keyword arguments directly to the run() method
#
# **Answer**: C

# %% [markdown]
# **Q5** In Qiskit Runtime Primitives V2, what does the resilience_level option control?
#
# - A
# The number of shots per circuit execution
#
# - B
# The degree of error mitigation applied to results
#
# - C
# The quantum circuit optimization level
#
# - D
# The classical post-processing algorithm
#
# **Answer**: B

# %% [markdown]
# **Q6** Why might you want to bypass runtime error mitigation and implement custom error mitigation?
#
# - A
# To apply domain-specific knowledge or experimental mitigation techniques
#
# - B
# Custom mitigation always executes faster
#
# - C
# Runtime mitigation is deprecated in V2
#
# - D
# Runtime mitigation is always less accurate than custom methods
#
# **Answer**: A

# %% [markdown]
# **Q7** Which option category would you modify to control dynamical decoupling sequences?
#
# - A
# resilience options
#
# - B
# transpilation options
#
# - C
# execution options
#
# - D
# environment options
#
# **Answer**: A

# %% [markdown]
# **Q8** What theoretical concept underlies the measurement process captured by the Sampler?
#
# - A
# Quantum Fourier transform
#
# - B
# Heisenberg uncertainty principle
#
# - C
# Quantum entanglement entropy
#
# - D
# Born rule and quantum measurement postulate
#
# **Answer**: D

# %% [markdown]
# **Q9** What is a key difference between Sampler V1 and Sampler V2?
#
# - A
# V2 eliminated the ability to set shot counts
#
# - B
# V2 introduced a more structured options interface
#
# - C
# V2 removed support for parameterized circuits
#
# - D
# V2 only works with simulators, not real hardware
#
# **Answer** B

# %% [markdown]
# **Q10** When implementing custom error mitigation with resilience_level=0, what raw data does the Sampler provide?
#
# - A
# Counts of measurement outcomes in the computational basis
#
# - B
# Quantum state vectors for each shot
#
# - C
# Density matrices of the output states
#
# - D
# Expectation values of Pauli operators
#
# **Answer**: A

# %% [markdown]
# **Q11** What is the purpose of setting multiple resilience levels during algorithm development?
#
# - A
# To compare accuracy versus computational cost trade-offs
#
# - B
# To enable automatic error correction codes
#
# - C
# To increase the number of available qubits
#
# - D
# To reduce total execution time by parallelizing jobs
#
# **Answer**: A

# %% [markdown]
# **Q12** In Qiskit Runtime Primitives V2, what is the main conceptual role of the Sampler primitive compared with the Estimator primitive?
#
# - A
# Sampler returns quasi-probability distributions over bitstrings, while Estimator returns expectation values of observables for given circuits and Hamiltonians
#
# - B
# Sampler performs full density-matrix tomography, while Estimator computes gate-level calibration parameters for noisy devices
#
# - C
# Sampler is restricted to Clifford circuits, while Estimator can handle arbitrary quantum circuits with non-Clifford gates
#
# - D
# Sampler executes circuits only on ideal simulators, while Estimator executes circuits only on real hardware backends
#
# **Answer**: A

# %% [markdown]
# **Q13** Suppose you want to implement a custom error-mitigation pipeline for Sampler results that bypasses Qiskit Runtime’s built-in resilience. Which configuration pattern best supports this workflow in an advanced setting?
#
# - A
# Use Estimator instead of Sampler so that the error mitigation is automatically turned off and your custom routine can operate directly on expectation values
#
# - B
# Configure Sampler to return only single-shot measurement outcomes without any aggregation, and ignore all quasi-probability outputs
#
# - C
# Always enable the highest resilience level in Sampler and then re-mitigate the already mitigated quasi-probabilities with your own method for extra accuracy
#
# - D
# Use Sampler with resilience disabled or set to the lowest level, request raw (unmitigated) quasi-probabilities, and apply your custom classical post-processing externally
#
# **Answer**: D

# %% [markdown]
# **Q14** You design an advanced workflow that uses Sampler quasi-probabilities as input to a classical optimizer that minimizes a cost function defined as an expectation value of a Hamiltonian $H$. Why might you still prefer to use Estimator directly for this task in Qiskit Runtime Primitives V2, rather than manually converting Sampler outputs into expectation values?
#
# - A
# Estimator can only be used with commuting Pauli Hamiltonians, while Sampler can handle arbitrary observables
#
# - B
# Estimator is optimized to compute expectation values directly, can apply observable-aware resilience strategies, and avoids extra classical post-processing noise when converting distributions to $⟨H⟩$
#
# - C
# Estimator always returns exact analytic expectation values without sampling error, whereas Sampler is fundamentally approximate
#
# - D
# Estimator forces you to work without any resilience or error mitigation, so your results are more faithful to the raw hardware behavior
#
# **Answer**: B

# %% [markdown]
# **Q15** Consider a parameterized circuit evaluated with Qiskit’s Sampler on a noisy device. You see that the estimated expectation value of a Pauli observable fluctuates noticeably between repeated runs with the same number of shots. Theoretically, which two main sources contribute to this variability?
#
# - A
# Only device noise; finite shots do not affect expectation values in practice
#
# - B
# Finite-shot sampling fluctuations and device noise described by a quantum channel acting on the ideal state
#
# - C
# The fact that Sampler uses deterministic simulation instead of sampling from the Born rule
#
# - D
# The randomness of the transpiler seed and the classical optimization algorithm’s learning rate
#
# **Answer**: D

# %% [markdown]
# **Q16** Pauli Twirling is often used in Qiskit to modify noise on a given two-qubit gate. What is the key theoretical idea behind Pauli Twirling?
#
# - A
# Randomly inserting Clifford gates so that coherent errors become purely classical readout errors
#
# - B
# Randomly reordering circuit gates to average out Trotterization errors in time-evolution simulations
#
# - C
# Replacing all noisy gates with ideal unitaries followed by classical sampling from a lookup table
#
# - D
# Randomly conjugating a channel by Pauli operators so that the effective noise becomes a Pauli channel with diagonal representation in the Pauli basis
#
# **Answer**: D

# %% [markdown]
# **Q17** In the context of Qiskit’s noise tailoring, why might Pauli Twirling sometimes increase the overall error rate, even though it simplifies the noise model?
#
# - A
# Because Pauli Twirling forces all gates to be simulated classically, adding approximation errors
#
# - B
# Because Pauli Twirling changes the target unitary so that the circuit no longer computes the desired algorithm
#
# - C
# Because Pauli Twirling introduces additional two-qubit gates that always have higher error rates than single-qubit gates
#
# - D
# Because converting coherent errors into stochastic Pauli errors can increase the average infidelity, even though the resulting channel is easier to model and mitigate
#
# **Answer**: D

# %% [markdown]
# **Q18** Dynamical Decoupling (DD) sequences can be inserted by Qiskit between idle periods of a circuit. What is the central theoretical mechanism by which DD protects quantum information?
#
# - A
# By repeatedly measuring idle qubits to project them back into their initial states
#
# - B
# By converting all coherent errors into stochastic Pauli channels using random twirls
#
# - C
# By encoding each logical qubit into multiple physical qubits through a stabilizer code
#
# - D
# By applying carefully timed sequences of control pulses that average out low-frequency environmental noise, effectively refocusing decoherence
#
# **Answer**: D

# %% [markdown]
# **Q19** When using Dynamical Decoupling in Qiskit, which trade-off is most important to consider from a theoretical and practical perspective?
#
# - A
# DD completely replaces the need for Pauli Twirling, so you must choose only one of them
#
# - B
# DD guarantees that the effective noise is exactly zero if the pulse sequence is long enough
#
# - C
# DD sequences always reduce both decoherence and gate errors, so there is no significant trade-off to consider
#
# - D
# DD can reduce decoherence during idle times but may add extra pulses that themselves have errors and can interfere with timing constraints
#
# **Answer**: D

# %% [markdown]
# **Q20** How can Pauli Twirling and Dynamical Decoupling be conceptually combined within a Qiskit workflow for error management?
#
# - A
# Use Dynamical Decoupling to transform decoherence into stochastic Pauli errors, and then apply Pauli Twirling to undo those errors
#
# - B
# They cannot be combined, because Pauli Twirling and Dynamical Decoupling rely on incompatible assumptions about the noise model
#
# - C
# Apply Pauli Twirling to tailor gate noise into a Pauli channel, while using Dynamical Decoupling to suppress decoherence during idle intervals, addressing complementary aspects of noise
#
# - D
# Use Pauli Twirling to completely eliminate noise, then Dynamical Decoupling to remove any remaining idle times
#
# **Answer**: C
