# %% [markdown]
# # Qiskit Certification – Section 8 Theory & Coding Practice
#
# Section 8: **Operate with OpenQASM**
#
# Topics covered here:
# - Structure types in OpenQASM 3 programs
# - Interpret OpenQASM semantics for versions 2 and 3
# - Interoperate different versions of OpenQASM with Qiskit
# - Interact with the Qiskit IBM Runtime REST API
#
# The quiz has 20 multiple choice format questions with A, B, C and D options, to test conceptual understanding and code-related knowledge. It covers key fundamental concepts such as OpenQASM 3 structure types, semantics for versions 2 and 3, Qiskit interoperability, IBM Runtime REST API, types/casting, syntax, and related documentation.

# %% [markdown]
# **Q1** In OpenQASM 2.0, which line correctly applies a controlled-NOT from qr[0] to qr[1]?
#
# - A
# CNOT(qr[0], qr[1]);
#
# - B
# cx(qr[0] qr[1]);
#
# - C
# cx qr[0], qr[1];
#
# - D
# cnx qr[0] -> qr[1];
#
# **Answer**: C

# %% [markdown]
# **Q2** You want to convert a Qiskit QuantumCircuit into its OpenQASM 2.0 string representation. Which method would you use?
#
# - A
# qasm_to_circuit(qc)
#
# - B
# qc.to_openqasm3()
#
# - C
# qc.to_qasm()
#
# - D
# qc.qasm()
#
# **Answer**: D

# %% [markdown]
# **Q3** In OpenQASM 3, which code snippet best declares a typed classical register of 8 unsigned bits and initializes it to the value 5 for use in a Qiskit-compatible circuit?
#
# - A
# "bit c = 5;"
#
# - B
# "uint c = 5;"
#
# - C
# "creg c = 5;"
#
# - D
# "int c = 5;"
#
# **Answer**: B

# %% [markdown]
# **Q4** You are inspecting an OpenQASM 3 file and encounter the following variable definition layout: int[16] loop_counter = 0;. What does the structural syntax definition [16] specify?
#
# - A
# The variable array size containing 16 separate integers.
#
# - B
# The explicit register address allocation slot on the classical controller module.
#
# - C
# The precision bit-width (16 bits) of a signed integer scalar type.
#
# - D
# The maximum iteration limit bound for associated loop constructs.
#
# **Answer**: C

# %% [markdown]
# **Q5** In OpenQASM 3, which declaration best represents a structured type that could naturally map to a Qiskit classical data container when exchanging programs via the Qiskit IBM Runtime REST API?
#
# - A
# "array Result { int values; }"
#
# - B
# "qreg Result;"
#
# - C
# "register Result { qubit q; }"
#
# - D
# "struct Result { bit flag; uint code; }"
#
# **Answer**: D

# %% [markdown]
# **Q6** Consider the following OpenQASM 3 snippet intended for use with Qiskit IBM Runtime:
# ```python
# input uint shots;
# qubit q;
# bit result;
# reset q;
# for i in [0:shots] {
#     h q;
#     measure q -> result;
# }
# ```
# What semantic issue does this code have regarding shots when targeting real hardware via Qiskit IBM Runtime?
#
# - A
# The variable result must be an integer, not a bit."
#
# - B
# shots must be a compile-time constant, but here it is treated as a runtime input.
#
# - C
# shots cannot be of integer type in OpenQASM 3.
#
# - D
# The loop index i cannot be declared implicitly in OpenQASM 3.
#
# **Answer**: B

# %% [markdown]
# **Q7** In OpenQASM 3, which cast correctly converts a single bit measurement result into a 1-bit unsigned integer for arithmetic with another uint value in a Qiskit-imported program?
#
# - A
# "bit(uint m)"
#
# - B
# "cast(m -> uint)"
#
# - C
# "int m;"
#
# - D
# "uint1" where m is of type bit
#
# **Answer**: D

# %% [markdown]
# **Q8** Which OpenQASM 3 construct most directly supports defining reusable quantum subroutines that can be imported into Qiskit as gates or subcircuits?
#
# - A
# "lambda" to define anonymous quantum functions at runtime
#
# - B
# "module" to define compiled binary components"
#
# - C
# "macro" to perform simple text substitution
#
# - D
# "def" to define quantum subroutines with typed parameters
#
# **Answer**: D

# %% [markdown]
# **Q9** When working with OpenQASM 2 versus OpenQASM 3 in Qiskit, which statement about their semantics is most accurate for measurement results and classical registers?
#
# - A
# OpenQASM 2 uses creg-based classical registers, while OpenQASM 3 replaces them with typed classical variables such as bit and uint[n].
#
# - B
# OpenQASM 2 allows arbitrary integer types for classical registers, while OpenQASM 3 restricts them to bit."
#
# - C
# OpenQASM 3 disallows classical measurement results; only OpenQASM 2 supports them.
#
# - D
# Both OpenQASM 2 and 3 require classical registers to be declared only with creg.
#
# **Answer**: A

# %% [markdown]
# **Q10** Which of the following OpenQASM 3 snippets shows a valid use of a structure type with both quantum and classical fields, compatible with Qiskit’s understanding of typed parameters?
#
# - A
# "struct Block { qreg q; int id; }"
#
# - B
# "struct Block { quantum q; classical id; }"
#
# - C
# "block Block { qubit q; uint id; }"
#
# - D
# "struct Block { qubit q; uint id; }"
#
# **Answer**: D

# %% [markdown]
# **Q11** In the context of Qiskit IBM Runtime’s REST API, how is an OpenQASM 3 program typically provided to the service, and what role does the qiskit_base language specification play?
#
# - A
# The REST API only accepts binary-encoded circuits; qiskit_base refers to a compiled binary format."
#
# - B
# The OpenQASM 3 file must be uploaded separately via FTP, and qiskit_base is not used.
#
# - C
# OpenQASM 3 programs are not accepted; only Qiskit Python objects can be submitted.
#
# - D
# The OpenQASM 3 source is sent as a string in the JSON payload with a language field like "language": "qiskit_base" indicating the supported subset.
#
# **Answer**: D

# %% [markdown]
# **Q12** What is a key difference in syntax between OpenQASM 2 and OpenQASM 3 for declaring quantum registers or qubits that Qiskit must handle when importing code?
#
# - A
# Both versions use exactly the same qreg declaration syntax.
#
# - B
# OpenQASM 3 uses qubits q; while OpenQASM 2 uses qubit q;.
#
# - C
# OpenQASM 3 disallows arrays of qubits; only OpenQASM 2 supports qreg."
#
# - D
# OpenQASM 2 uses qreg q; while OpenQASM 3 uses qubit q;.
#
# **Answer**: D

# %% [markdown]
# **Q13** Which OpenQASM 3 statement best demonstrates interoperability with Qiskit by using a parameter that Qiskit can bind at runtime via its parameter binding mechanisms?
#
# - A
# "input float theta;" followed by rx(theta) q;
#
# - B
# "param theta;" followed by rx(theta) q;
#
# - C
# "bind theta;" followed by rx(theta) q;
#
# - D
# "float theta = 0.5;" followed by rx(theta) q;
#
# **Answer**: A

# %% [markdown]
# **Q14** You need to represent a classical outcome in OpenQASM 3 that is either "success" or "failure" and make it easy for Qiskit IBM Runtime to return this through the REST API. Which OpenQASM 3 approach is most suitable?
#
# - A
# Store the outcome in a bit array with "s" and "f" encoded as bits.
#
# - B
# Use a qubit variable and assign it 0 or 1.
#
# - C
# Use an enum-like pattern with uint and document 0 as "failure" and 1 as "success".
#
# - D
# OpenQASM 3 has a built-in string type; use string outcome;."
#
# **Answer**: C

# %% [markdown]
# **Q15** Which of the following is a correct way in OpenQASM 3 to declare a function that returns a uint and could be used by Qiskit to perform classical pre-processing inside the quantum program?
#
# - A
# "def add_one(uint x) -> uint { return x + 1; }"
#
# - B
# "function add_one(uint x): uint { return x + 1; }"
#
# - C
# "def add_one(x: uint) uint { return x + 1; }"
#
# - D
# "uint add_one(uint x) { return x + 1; }"
#
# **Answer**: A

# %% [markdown]
# **Q16** In OpenQASM 3, how would you correctly write a conditional that applies an x gate to qubit q if classical bit variable c is 1, in a way that Qiskit can interpret as a measurement-based conditional?
#
# - A
# "when c == 1 do x q;"
#
# - B
# "condition(c == 1) x q;"
#
# - C
# "if c then x q;"
#
# - D
# "if (c == 1) { x q; }"
#
# **Answer**: D

# %% [markdown]
# **Q17** You are authoring documentation for developers preparing for the Qiskit Developer Exam on OpenQASM. Which statement best describes how Qiskit treats OpenQASM 3 types during import, particularly for structure types and integers?
#
# - A
# Qiskit only supports OpenQASM 3 if all classical types are bit with no structs or integers.
#
# - B
# Qiskit discards all type information from OpenQASM 3 and treats everything as untyped bits and qubits.
#
# - C
# Qiskit converts all OpenQASM 3 structs into separate scalar variables, never keeping any notion of grouping."
#
# - D
# Qiskit attempts to preserve OpenQASM 3 type information, mapping structs and integers to appropriate Python and circuit objects while possibly simplifying some types for backend execution.
#
# **Answer**: D

# %% [markdown]
# **Q18** Look at the following two syntax expressions describing measurement operations. How do OpenQASM 2 and OpenQASM 3 interpret these semantics?
#
# Expression A:
# measure q -> c;
#
# Expression B:
# c = measure q;
#
# - A
# Expression A is exclusive to OpenQASM 3, while Expression B is unique to OpenQASM 2.
#
# - B
# Expression A is standard OpenQASM 2 syntax (though supported by OpenQASM 3 for backwards compatibility), whereas Expression B is native functional assignment syntax introduced in OpenQASM 3.
#
# - C
# Expression B is an illegal memory assignment constraint across all variations of quantum intermediate representations.
#
# - D
# Both formats execute destructive projection, but Expression B automatically resets the qubit to state $\vert0\rangle$.
#
# **Answer**: B

# %% [markdown]
# **Q19** In OpenQASM 2, conditional branch statements were restricted to checking a whole classical register equality using the if keyword (if(c==1) U(theta) q;). How does OpenQASM 3 expand on this runtime semantic capability?
#
# - A
# It permits arbitrary boolean logic, else control branches, nested scoped block configurations, and variable conditional evaluations on classical parameters.
#
# - B
# OpenQASM 3 limits logic loops exclusively to pure hardware pulse changes.
#
# - C
# It permits conditional branches to inspect non-measured quantum coherence states directly.
#
# - D
# OpenQASM 3 drops standard conditional if processing completely to force developers onto dynamic circuit runtime primitives.
#
# **Answer**: A

# %% [markdown]
# **Q20** You have a Python string variable named qasm_str containing a complete OpenQASM 3 script. Which method should you import from qiskit.qasm3 to reconstruct this string into a standard, executable Qiskit QuantumCircuit instance?
#
# - A
# QuantumCircuit.from_qasm_str(qasm_str)
#
# - B
# from qiskit.qasm3 import loads; qc = loads(qasm_str)
#
# - C
# from qiskit.qasm3 import dump; qc = dump(qasm_str)
#
# - D
# from qiskit import load_qasm; qc = load_qasm(qasm_str)
#
# **Answer**: B
